# %%
# Pandas for managing datasets
import pandas as pd

# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline

# Seaborn for plotting and styling
import seaborn as sns

# Numpy, Statistics and Random for math
import numpy as np
import random as rand
import statistics
import scipy.signal

# Warnings to remove complex to real conversion warnings
import warnings
warnings.filterwarnings('ignore')

# Scikit Learn for Machine Learning
import sklearn
from sklearn import metrics 
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree

# SoundFile to for opening raw audio files
import soundfile as sf

# %%
def getAudioData(filename):
    # Load Raw Audio Data into [sig] and [sr]
    sig, sr = sf.read(filename+'.raw', channels=2, samplerate=62500, format='RAW', subtype='PCM_16')

    # Define an empty array to store the combined audio channels
    data = []

    # Average the left and right audio channels and store in [data]
    for i in range(0, len(sig)):
        average = (sig[i][0]+sig[i][1])/2
        data.append(average)
    return data

def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

def returnShape(*args):
    return np.broadcast(*args).shape

def calculateLabel(labels):
    total = sum(labels)
    num = len(labels)
    if total/num > 0.4:
        return 1
    else:
        return 0
    #return int(round(total/num))

def splitDataFrameIntoSmaller(df, chunkSize = 10000): 
    listOfDf = list()
    numberChunks = len(df) // chunkSize + 1
    for i in range(numberChunks):
        listOfDf.append(df[i*chunkSize:(i+1)*chunkSize])
    return listOfDf

def convertToReal(c):
    return (c.real**2)+(c.imag**2)

def mean(array):
    return np.mean(array, dtype=np.float64)

def median(array):
    return np.median(array)

def energy(array, wSize):
    array = list(map(int, array))
    fft = np.fft.fft(array)
    sum = 0
    for i in range(0, len(fft)):
        sum = sum + (fft[i]*fft[i])
    return float(sum)/wSize

def meanFFT(array):
    fft = np.fft.fft(array)
    return convertToReal(mean(fft))

def medianFFT(array):
    fft = np.fft.fft(array)
    return convertToReal(median(fft))

def maxFFT(array):
    fft = np.fft.fft(array)
    return convertToReal(max(fft))

def minFFT(array):
    fft = np.fft.fft(array)
    return convertToReal(min(fft))

def sumFFT(array):
    fft = np.fft.fft(array)
    return convertToReal(sum(fft))

def stdevFFT(array):
    fft = np.fft.fft(array)
    return statistics.stdev(list(map(convertToReal, fft)))

# %%
# Generate Window Sizes
windowSizes = list(np.arange(300, 9001, 300))
print(windowSizes)
# Out:
# [300, 600, 900, 1200, 1500, 1800, 2100, 2400, 2700, 3000, 3300, 3600, 3900, 4200, 4500, 4800, 5100, 5400, 5700, 6000, 6300, 6600, 6900, 7200, 7500, 7800, 8100, 8400, 8700, 9000]

# %%
# Open the .csv that information about the audio files # signed 8 bit pcm 62500 hz
data_loc = pd.read_csv('DataLoc.csv').values
#print(data_loc)

audio_data = []
for i in range(0, len(data_loc)):
    audio_sig = getAudioData(data_loc[i][2])
    
    starting_silence = [0]*data_loc[i][0]
    speaking = [1]*(data_loc[i][1]-data_loc[i][0])
    ending_silence = [0]*(len(audio_sig) - data_loc[i][1])
    
    labels = starting_silence+speaking+ending_silence
    
    audio_data.append([audio_sig, labels])
    
for i in range(0, len(audio_data)):
    with open(str(i)+'.csv', 'a+') as csv:
        csv.seek(0)
        csv.truncate()
        csv.write('sig,label,fileID\n')
        for j in range(0, len(audio_data[i][0])):
            #print(returnShape(audio_data[i]))
            sig = str(audio_data[i][0][j])
            label = str(audio_data[i][1][j])
            csv.write(sig+','+label+','+str(i)+'\n')

# %%
windows = []
for i in range(0, 8):
    windows.append(pd.read_csv(str(i)+'.csv'))

# %%
features = []
for i in range(0, len(windows)):
    for j in range(0, len(windowSizes)):
        data = splitDataFrameIntoSmaller(windows[i], windowSizes[j])
        for k in range(0, len(data)-1):
            windowSize = float(windowSizes[j])
            sig = list(map(float, data[k]['sig']))
            label = calculateLabel(data[k]['label'].values)
            ID = median(data[k]['fileID'].values)
            #print(ID)
            
            features.append([ID, windowSize, mean(sig), median(sig), min(sig), 
                                        max(sig), sum(sig), statistics.stdev(sig), meanFFT(sig), 
                                        medianFFT(sig), minFFT(sig), maxFFT(sig), sumFFT(sig), stdevFFT(sig), label])
        #dataFrame.to_csv('Data\\'+str(i)+' '+str(j)+'.csv', sep=',', header=False)
dataFrame = pd.DataFrame(data=features) 
dataFrame.columns = ['fileID','windowSize','mean','median','min','max','sum','stdev','meanFFT','medianFFT','minFFT','maxFFT','sumFFT','stdevFFT','label']
dataFrame.to_csv('Windows.csv', sep=',', index=False)

# %%
file_num = [0, 1, 2, 3, 4, 5, 6, 7]
items = rand.sample(file_num, 1)
print(items)
# Out:
# [5]

# %%
data = pd.read_csv('Windows.csv')
data = clean_dataset(data)
#print data.head()
dataColumns = ['mean','median','min','max','sum','stdev','meanFFT','medianFFT','minFFT','maxFFT','sumFFT','stdevFFT']

accuracy = {}
matrix = []
chart = []
zero_r_x = []
zero_r_y = []

# Loop through all window Sizes
for i in range(0, len(windowSizes)):
    ## print('i')
    ## print(i)
    # Define variables to store the mean accuracy, and the current window size
    mean = []
    windowSize = windowSizes[i]
    
    # Loop through all of the randomly chosen files
    for j in range(0, len(file_num)):
        # Define vairable to store the 2 query strings and store the confusion matrix
        string = '('
        string2 = '('
        
        conf_matrix = [0]*4
        
        # Loop through all of the randomly chosen files and update the query strings
        for k in range(0, len(file_num)):
            if  (file_num[k]  in items) or k == j:
                string2 += 'fileID=='+str(file_num[k])+' or '
            else:
                string += 'fileID=='+str(file_num[k])+' or '
        
        # Finish editing the query strings
        string = string[:-3] + ') and windowSize=='+str(windowSize)
        string2 = string2[:-3]+') and windowSize=='+str(windowSize)
        
        #print(string)
        #print(string2)
        
        # Use the query strings to genereate train and test, data and values
        trainDataValues = data.query(string).filter(items=dataColumns)
        trainLabels = data.query(string).filter(items=['label'])
        testDataValues = data.query(string2).filter(items=dataColumns)
        testLabels = data.query(string2).filter(items=['label'])
        
        # Initilize the Naive Bayes classifier
        mnb = GaussianNB()
        mnb = RandomForestClassifier(n_estimators=200, max_depth=5, random_state=0)
        
        # Train and predict the classifier
        mnb.fit(trainDataValues, trainLabels)
        predicted = mnb.predict(testDataValues)
        
        # Store the accuracy in [fold], [mean] and [matrix]
        fold = metrics.accuracy_score(testLabels,predicted)
        mean.append(fold)
        matrix.append([windowSize,fold,file_num[j]])
        conf_matrix = np.add(conf_matrix, metrics.confusion_matrix(testLabels, predicted).ravel())
        accuracy.update({metrics.accuracy_score(testLabels,predicted):i})
    print(np.divide(conf_matrix, float(len(file_num))))
    chart.append([windowSize,np.mean(mean)])
    length = data.query('windowSize == '+str(windowSize)).shape[0]
    not_talking = data.query('windowSize == '+str(windowSize)+' and label == 0').shape[0]
    # print(str(length)+','+str(not_talking))
    acc = float(not_talking)/length
    zero_r_y.append(acc)
    zero_r_x.append(windowSize)
    accuracy.update({np.mean(mean):windowSize})
matrix = pd.DataFrame(matrix, columns=['windowSize','accuracy','fileID'])
matrix.to_csv('windowResults.csv', sep=',', index=False)
#print accuracy
#print matrix
chart = pd.DataFrame(chart, columns=['windowSize','accuracy'])
# Out:
# [ 65.375   0.25    5.625  14.75 ]
# [ 32.625   0.375   3.      7.   ]
# [ 21.875   0.125   2.      4.625]
# [ 16.625   0.      1.375   3.375]
# [ 13.125   0.125   1.375   2.5  ]
# [ 11.      0.125   1.      2.125]
# [ 9.25   0.125  1.     1.75 ]
# [ 8.25   0.125  0.75   1.5  ]
# [ 7.375  0.     0.625  1.375]
# [ 6.75   0.     0.625  1.125]
# [ 6.     0.125  0.5    1.125]
# [ 5.5    0.     0.625  0.875]
# [ 5.     0.125  0.625  0.75 ]
# [ 4.625  0.125  0.5    0.75 ]
# [ 4.5    0.     0.5    0.625]
# [ 4.    0.25  0.5   0.5 ]
# [ 4.     0.     0.25   0.625]
# [ 3.75   0.     0.5    0.375]
# [ 3.5    0.125  0.25   0.625]
# [ 3.25  0.25  0.25  0.5 ]
# [ 3.25   0.     0.375  0.375]
# [ 3.125  0.125  0.25   0.375]
# [ 3.     0.     0.375  0.25 ]
# [ 2.625  0.125  0.25   0.375]
# [ 2.5    0.25   0.375  0.25 ]
# [ 2.625  0.     0.125  0.5  ]
# [ 2.5   0.    0.25  0.25]
# [ 2.375  0.125  0.25   0.25 ]
# [ 2.    0.25  0.25  0.25]
# [ 2.375  0.     0.375  0.   ]

# %%
y = chart['accuracy']
x = chart['windowSize']
plt.plot(x, y)
plt.plot(zero_r_x, zero_r_y)
plt.ylim(0, 1)
plt.xlabel('Window Size')
plt.ylabel('Accuracy')
print('Best Accuracy:')
print(max(chart['accuracy'].values))
# Out:
# Best Accuracy:
# 0.964025444664

# %%
### Real-Time Detection ###
from __future__ import print_function
import pyaudio
import sys
import time


FORMAT = pyaudio.paInt16 # We use 16 bit format per sample
CHANNELS = 1
RATE = 62500
CHUNK = 300 # 1024 bytes of data read from the buffer

audio = pyaudio.PyAudio()

# Claim the microphone
stream = audio.open(format=FORMAT,
                    channels=CHANNELS,
                    rate=RATE, 
                    input=True,
                    frames_per_buffer=CHUNK)

test = pd.read_csv('Windows.csv')
test = clean_dataset(test)

dataColumns = ['mean','median','min','max','sum','stdev','meanFFT','medianFFT','minFFT','maxFFT','sumFFT','stdevFFT']
trainDataValues = test.query('windowSize==300').filter(items=dataColumns)
trainLabels = test.query('windowSize==300').filter(items=['label'])
print('got data')

clf = tree.DecisionTreeClassifier()
clf.fit(trainDataValues, trainLabels)
tree.export_graphviz(clf,out_file='tree.dot')

mnb = RandomForestClassifier(n_estimators=200, max_depth=5, random_state=0)
mnb.fit(trainDataValues, trainLabels)
print('trained model')

sig = np.fromstring(stream.read(CHUNK, exception_on_overflow = False), np.int16)
#print mnb.predict([[mean(sig),median(sig),min(sig),max(sig),sum(sig),statistics.stdev(sig),meanFFT(sig),medianFFT(sig),minFFT(sig),maxFFT(sig),sumFFT(sig),stdevFFT(sig)]])

while True:
    sig = np.fromstring(stream.read(CHUNK, exception_on_overflow = False), np.int16)
    features = [mean(sig),median(sig),min(sig),max(sig),sum(sig),statistics.stdev(sig),meanFFT(sig),medianFFT(sig),minFFT(sig),maxFFT(sig),sumFFT(sig),stdevFFT(sig)]
    prediction = mnb.predict([features])
    print(prediction, end='\r')
    sys.stdout.flush()
    if prediction == 1:
        time.sleep(1)
    '''
    try:
        print mnb.predict([np.average(np.fromstring(stream.read(CHUNK, exception_on_overflow = False), np.int16))])
    except KeyboardInterrupt:
        keep_going=False
    except:
        pass
    '''

# Close up shop 
stream.stop_stream()
stream.close()

audio.terminate()
# Out:
# got data
# trained model
# [0.]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-5251f3e8e6b0> in <module>()
#      41 while True:
#      42     sig = np.fromstring(stream.read(CHUNK, exception_on_overflow = False), np.int16)
# ---> 43     features = [mean(sig),median(sig),min(sig),max(sig),sum(sig),statistics.stdev(sig),meanFFT(sig),medianFFT(sig),minFFT(sig),maxFFT(sig),sumFFT(sig),stdevFFT(sig)]
#      44     prediction = mnb.predict([features])
#      45     print(prediction, end='\r')
#
# <ipython-input-20-4f8d5d216bfb> in stdevFFT(array)
#      70 def stdevFFT(array):
#      71     fft = np.fft.fft(array)
# ---> 72     return statistics.stdev(list(map(convertToReal, fft)))
#
# /usr/local/lib/python2.7/site-packages/statistics/__init__.pyc in stdev(data, xbar)
#     575
#     576     """
# --> 577     var = variance(data, xbar)
#     578     try:
#     579         return var.sqrt()
#
# /usr/local/lib/python2.7/site-packages/statistics/__init__.pyc in variance(data, xbar)
#     514     if n < 2:
#     515         raise StatisticsError(u'variance requires at least two data points')
# --> 516     ss = _ss(data, xbar)
#     517     return ss/(n-1)
#     518
#
# /usr/local/lib/python2.7/site-packages/statistics/__init__.pyc in _ss(data, c)
#     462     """
#     463     if c is None:
# --> 464         c = mean(data)
#     465     ss = _sum((x-c)**2 for x in data)
#     466     # The following sum should mathematically equal zero, but due to rounding
#
# /usr/local/lib/python2.7/site-packages/statistics/__init__.pyc in mean(data)
#     293     if n < 1:
#     294         raise StatisticsError(u'mean requires at least one data point')
# --> 295     return _sum(data)/n
#     296
#     297
#
# /usr/local/lib/python2.7/site-packages/statistics/__init__.pyc in _sum(data, start)
#     163         _check_type(type(x), allowed_types)
#     164         n, d = exact_ratio(x)
# --> 165         partials[d] = partials_get(d, 0) + n
#     166     # Find the expected result type. If allowed_types has only one item, it
#     167     # will be int; if it has two, use the one which isn't int.
#
# KeyboardInterrupt:

# %%
### One R ###

test = pd.read_csv('Windows.csv')
test = clean_dataset(test)

dataColumns = ['mean','median','min','max','sum','stdev','meanFFT','medianFFT','minFFT','maxFFT','sumFFT','stdevFFT']
trainDataValues = test.query('windowSize==300 and fileID!=0').filter(items=dataColumns)
trainLabels = test.query('windowSize==300 and fileID!=0').filter(items=['label'])

testDataValues = test.query('windowSize==300 and fileID==0').filter(items=dataColumns)
testLabels = test.query('windowSize==300 and fileID==0').filter(items=['label'])

best_clf = None
best_accuracy = 0
best_feature = 0
for i in range(0, len(dataColumns)):
    feature = dataColumns[i]
    clf = tree.DecisionTreeClassifier(max_depth=1)
    clf.fit(trainDataValues.filter(items=[feature]), trainLabels)
    predicted = clf.predict(testDataValues.filter(items=[feature]))
    accuracy = metrics.accuracy_score(testLabels,predicted)
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_clf = clf   
        best_feature = feature

print(best_feature)
print(accuracy)
tree.export_graphviz(best_clf,out_file='r1.dot')
# Out:
# median
# 0.8801955990220048
